# %%
# allow import with no install
import sys
sys.path.append("..")

# %%
from spacial_transcriptomics_viz import tsne_display

# %%
filename = "/Users/awatters/misc/tarmo/spatial_transcriptomics_example_data_02222017.tsv"

# %%
data = tsne_display.Data(filename)
S = tsne_display.Slides(data)

# %%
S.show()
# Out:
# enabling tsne events click mousedown mouseup mousemove mouseout
# lasso_start (5.338983050847458, -3.559322033898305)
# lasso_start (5.338983050847458, -3.559322033898305)
# lasso complete
# lasso complete
# lasso_start (5.491525423728813, -3.559322033898305)
# lasso_start (5.491525423728813, -3.559322033898305)
# lasso complete
# lasso complete
# lasso_start (-5.59322033898305, 3.711864406779661)
# lasso complete
